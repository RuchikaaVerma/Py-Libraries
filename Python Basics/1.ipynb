# %% [markdown]
# Classes and Objects
#
# OOP's is a programming paradigm that uses "objects " to design applications and computer programs . OOP allows for modeling real-world scenarios using classes and objects.

# %%
# Classis a blueprint for creating objects
# Objects have properties and behaviors(functions) associated with them.
class car:
    pass
audi=car()
bmw=car()
print(type(audi))
# Out:
# <class '__main__.car'>

# %%
print(audi)#at this specific location
