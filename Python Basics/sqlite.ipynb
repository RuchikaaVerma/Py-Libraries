# %% [markdown]
# SQL and SQLite
#
# SQL is a standard query language for managing and manipulating relational databases ,SQlite is a self conatined,serverless and zero comnfigurated database engine that is widely used for embedded  databse sysetems .

# %%
import sqlite3

# %%
#connect to an SQLite databse
connection=sqlite3.connect('example.db')
connection

# %%
cursor=connection.cursor()

# %%
#Create a table
cursor.execute()
