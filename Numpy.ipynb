# %% [markdown]
# NumPy
#
# NumPy is a fundamental library for scientific computing in Python.It provides support for arrays and matrices, along eith a collection of mathematical functions to operate on these data structures .

# %%
# !pip install numpy

# %%
import numpy as np
arr=np.array([3,4,5])
print(arr)
print(type(arr))
print(arr.shape)
# Out:
# [3 4 5]
# <class 'numpy.ndarray'>
# (3,)

# %%
#reshape
arr2=np.array([[1,2,3],[4,5,6]])
arr2=np.reshape(arr2, (3,2))
print(arr2)
# Out:
# [[1 2]
#  [3 4]
#  [5 6]]
