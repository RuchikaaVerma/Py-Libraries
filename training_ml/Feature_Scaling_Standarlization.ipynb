# %%
import pandas as pd#data processing
import numpy as np#linear algebra

# %%
df=pd.read_csv("Social_Network_Ads.csv")

# %%
df=df.iloc[:,2,:]

# %%
df.sample(5)

# %% [markdown]
# TrainTest Split

# %%
from sklearn.model_selection import train_test_split
X_train,X-train,y_test,y_test=train_split(df.drop("Purchased",axis=1),
                        df['Purchased'],test_size=0.3,random_state=0)
x_train.shape,X_test.shape

# %% [markdown]
# StandardScaler

# %%
from sklearn.preprocessing import StandardScaler
scaler=StandardScaler()
scaler.fit(X_train)
X_train_scaled =scaler.transform(X_train)
X_test_scaled =scaler.transform(X_test)#learn from training  only but both are transformed test and train.

# %%
scaler.mean()

# %%
X_train_scaled=pd.DataFrame(X_train_scaled,columns=X_train.columns)
X_test_scaled=pd.DataFrame(X_test_scaled,columns=X_test.columns)

# %%
np.round(X_train.describe(),1)

# %% [markdown]
# Why scaling important?

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression()
lr_scaled=LogisticRegression

# %%
y_pred=lr.predict(X_test)
y_pred_scaled=lr_scaled.predict(X_test_scaled)

# %%
print("Actual",accuracy_score(y_test,y_pred))
print("Scaled",accuracy_score(y_test,y_pred_scaled))

# %%
df.describe()

# %% [markdown]
# Effect of Outliers-handled explicitly
