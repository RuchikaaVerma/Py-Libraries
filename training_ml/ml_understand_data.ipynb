# %%
import pandas as pd

# %%
df=pd.read_csv('train.csv')

# %% [markdown]
# 1.How big the data?

# %%
df.shape#define no. of rows and cols
# Out:
# (891, 12)

# %% [markdown]
# 2.How does the data look like?

# %%
df.head()#first 5 rows
df.sample(5)#random 5 rows
# Out:
#      PassengerId  Survived  Pclass                           Name     Sex  \
# 71            72         0       3     Goodwin, Miss. Lillian Amy  female
# 500          501         0       3               Calic, Mr. Petar    male
# 345          346         1       2  Brown, Miss. Amelia "Mildred"  female
# 859          860         0       3               Razi, Mr. Raihed    male
# 320          321         0       3             Dennis, Mr. Samuel    male
#
#       Age  SibSp  Parch     Ticket     Fare Cabin Embarked
# 71   16.0      5      2    CA 2144  46.9000   NaN        S
# 500  17.0      0      0     315086   8.6625   NaN        S
# 345  24.0      0      0     248733  13.0000   F33        S
# 859   NaN      0      0       2629   7.2292   NaN        C
# 320  22.0      0      0  A/5 21172   7.2500   NaN        S

# %% [markdown]
# 3.What is the data tyoe of cols?

# %%
df.info()#data type of cols and non-null values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %% [markdown]
# 4.Are there any misssing values?

# %%
df.isnull().sum()#missing values
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# 5.How does the data look mathematically?

# %%
df.describe()#mathematical look of data to give high level data on numerical cols
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %% [markdown]
# 6.Are there duplicate values?

# %%
df.duplicated().sum()#duplicate values removed by drop_duplicates()
# Out:
# 0

# %% [markdown]
# 7.How is the correlation between cols?

# %%
#df.corr()#correlation between cols(-1,1)
#df.corr()['Survived']

# %% [markdown]
# EDA Analysis

# %% [markdown]
# The preliminary analysis of data to discover relationships between measures in the data and to gain an insight on the trends, patterns, and relationships among various entities present in the data set with the help of statistics and visualization tools is called Exploratory Data Analysis (EDA).
#
# Exploratory data analysis is cross-classified in two different ways where each method is either graphical or non-graphical. And then, each method is either univariate, bivariate or multivariate.
#
# Uni means one and variate means variable, so in univariate analysis, there is only one dependable variable. The objective of the univariate analysis is to derive the data, define and summarize it, and analyze the pattern present in it. In a dataset, it explores each variable separately. It is possible for two kinds of variables- Categorical and Numerical.

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 1.Categorical Data

# %% [markdown]
# a.Countplot

# %%
import seaborn as sns
sns.countplot(df['Survived'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Survived'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Survived'>

# %%
sns.countplot(df['Pclass'])
# Out:
# <Axes: ylabel='count'>

# %%
sns.countplot(df['Embarked'])
# Out:
# <Axes: xlabel='count', ylabel='Embarked'>

# %%
sns.countplot(df['Name'])
# Out:
# <Axes: xlabel='count', ylabel='Name'>

# %%
sns.countplot(df['Age'])
# Out:
# <Axes: ylabel='count'>

# %%
df['Pclass'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
df['Age'].value_counts().plot(kind='bar')#numerical data
# Out:
# <Axes: xlabel='Age'>

# %%
df['Name'].value_counts().plot(kind='bar')#numerical data
# Out:
# <Axes: xlabel='Name'>

# %% [markdown]
# b.PieChart

# %%
df['Survived'].value_counts().plot(kind="pie",autopct='%.2f')
# Out:
# <Axes: ylabel='count'>

# %% [markdown]
# 2.Numerical Data

# %% [markdown]
# a.Histogram

# %%
#numerical data range bin is created
import matplotlib.pyplot as plt
plt.hist(df['Age'],bins=5)
# Out:
# (array([100., 346., 188.,  69.,  11.]),
#  array([ 0.42 , 16.336, 32.252, 48.168, 64.084, 80.   ]),
#  <BarContainer object of 5 artists>)

# %% [markdown]
# b.Distplot

# %%
sns.distplot(df['Age'])
# Out:
# C:\Users\Ruchika Verma\AppData\Local\Temp\ipykernel_21656\3255828239.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %% [markdown]
# C.BoxPlot

# %%
sns.boxplot(df['Fare'])
# Out:
# <Axes: ylabel='Fare'>

# %%
sns.boxplot(df['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
df['Age'].min()
# Out:
# 0.42

# %%
df['Age'].shew()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_21656\2456445982.py in ?()
# ----> 1 df['Age'].shew()
#
# c:\ProgramData\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'shew'

# %% [markdown]
# 2.Bivariate Analysis

# %%
import pandas as pd
import seaborn as sns

# %%
df=sns.load_dataset('tips')

# %%
titanic=pd.read_csv('train.csv')

# %%
flights=sns.load_dataset('flights')

# %%
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
iris=sns.load_dataset('iris')

# %%
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
tips=sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %% [markdown]
# 1.Scatterplot(Numerical-Numerical)

# %%
sns.scatterplot(x='total_bill',y='tip',data=tips)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# 3.Multivariate

# %%
sns.scatterplot(x=tips['total_bill'], y=tips['tip'], hue=tips['sex'],style=tips['smoker'],size=tips['size'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# 2.Bar Plot (Numerical -Categorical)

# %%
sns.barplot(x=titanic['Pclass'],y=titanic['Age'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %%
sns.barplot(x=titanic['Pclass'],y=titanic['Age'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# 3.Box Plot(Numerical-Categorical)

# %%
sns.boxplot(x=titanic['Pclass'],y=titanic['Age'],hue=titanic['Sex'])
# Out:
# <Axes: xlabel='Pclass', ylabel='Age'>

# %% [markdown]
# 4.Distplot(Numerical -Categorical)

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'])
# Out:
# C:\Users\Ruchika Verma\AppData\Local\Temp\ipykernel_21656\788471028.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'])
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
sns.distplot(titanic[titanic['Survived']==1]['Age'],hist=False)
# Out:
# C:\Users\Ruchika Verma\AppData\Local\Temp\ipykernel_21656\3138067409.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(titanic[titanic['Survived']==0]['Age'],hist=False)
# C:\Users\Ruchika Verma\AppData\Local\Temp\ipykernel_21656\3138067409.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# ...

# %% [markdown]
# 5.HeatMap(Categorical-Categorical)

# %%
pd.crosstab(titanic['Pclass'],titanic['Survived'])
# Out:
# Survived    0    1
# Pclass
# 1          80  136
# 2          97   87
# 3         372  119

# %%
sns.heatmap(pd.crosstab(titanic['Pclass'],titanic['Survived']),annot=True,fmt='d')
# Out:
# <Axes: xlabel='Survived', ylabel='Pclass'>

# %%
titanic.groupby('Pclass')['Survived'].mean().mul(100).plot(kind='bar')
# Out:
# <Axes: xlabel='Pclass'>

# %%
titanic.groupby('Sex')['Survived'].mean().mul(100)
# Out:
# Sex
# female    74.203822
# male      18.890815
# Name: Survived, dtype: float64

# %%
titanic.groupby('Embarked')['Survived'].mean().mul(100)
# Out:
# Embarked
# C    55.357143
# Q    38.961039
# S    33.695652
# Name: Survived, dtype: float64

# %%
titanic.groupby('Pclass')[['Survived']].mean()
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# 6.Clustermap(Categorical -Categoriacal)

# %%
pd.crosstab(titanic['SibSp'],titanic['Survived'],margins=True)
# Out:
# Survived    0    1  All
# SibSp
# 0         398  210  608
# 1          97  112  209
# 2          15   13   28
# 3          12    4   16
# 4          15    3   18
# 5           5    0    5
# 8           7    0    7
# All       549  342  891

# %%
sns.clustermap(pd.crosstab(titanic['SibSp'],titanic['Survived']))

# %% [markdown]
# 7.Pairplot

# %%
#collection of scatterplot
sns.pairplot(iris)

# %%
sns.pairplot(iris,hue='species')

# %% [markdown]
# 8.Lineplot(Numerical-Numerical)

# %%
#special case of scatter plot
flights['year'] = flights['year'].astype(int)  # or float if needed
new = flights.groupby('year').sum(numeric_only=True).reset_index()

# %%
sns.lineplot(x=new['year'],y=new['passengers'])
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
flights.pivot_table(values='passengers',index='month',columns='year')
# Out:
# C:\Users\Ruchika Verma\AppData\Local\Temp\ipykernel_16272\2056291100.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   flights.pivot_table(values='passengers',index='month',columns='year')
# year    1949   1950   1951   1952   1953   1954   1955   1956   1957   1958  \
# month
# Jan    112.0  115.0  145.0  171.0  196.0  204.0  242.0  284.0  315.0  340.0
# Feb    118.0  126.0  150.0  180.0  196.0  188.0  233.0  277.0  301.0  318.0
# Mar    132.0  141.0  178.0  193.0  236.0  235.0  267.0  317.0  356.0  362.0
# Apr    129.0  135.0  163.0  181.0  235.0  227.0  269.0  313.0  348.0  348.0
# May    121.0  125.0  172.0  183.0  229.0  234.0  270.0  318.0  355.0  363.0
# Jun    135.0  149.0  178.0  218.0  243.0  264.0  315.0  374.0  422.0  435.0
# Jul    148.0  170.0  199.0  230.0  264.0  302.0  364.0  413.0  465.0  491.0
# ...

# %%
sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# C:\Users\Ruchika Verma\AppData\Local\Temp\ipykernel_16272\2230379170.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.heatmap(flights.pivot_table(values='passengers',index='month',columns='year'))
# <Axes: xlabel='year', ylabel='month'>

# %%
sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
# Out:
# C:\Users\Ruchika Verma\AppData\Local\Temp\ipykernel_16272\1868718285.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   sns.clustermap(flights.pivot_table(values='passengers',index='month',columns='year'))
