# %% [markdown]
# Generative ai -the boiggest revolution came in the feild of Ai [the time where fuzzy algo,sybolism exist ]that can mimic the human creativity in seconds.
# It creates a new content -such as text,images,vedios,music or code -by learning patterns from existing data,mimicking human creativity.
#
# Gen ai was originated after the transformer model .

# %% [markdown]
# Impact areas-
# >Customer Support(customer support team by chatbots),
#
# >content creation,
#
# >Education,
#
# >Software Development

# %% [markdown]
# Lanchain is an open ource framework hepls in buidling LLM based Applications.
#
# >Provide modular components and end to end tolls that help developers build
#
# >Eg-chatbot,RAG(REtreieval Augmented Generation),autonomous agents.
#
# >
# Support the major LLMS,
# simplies developing LLm based applications,intergation avaible for all major tools,
# Open source/free/active deveopment,
# Support gen ai use cases

# %% [markdown]
# Steps to setup-
#
# >Create a virtual environment -python -m venv venv
#
# >activate venv-venv/Scripts/Activate
#
# >create requirments.txt = install packages
#
# pip install -r requirments.txt
#
# >.env file -store scret keys and  env variables

# %%
#checking langchain instalation
import langchain
print(langchain.__version__)
# Out:
# 0.3.27
