# %%
from langchain_openai import ChatOpenAI
from dotenv import load_dotenv
import streamlit as st
from langchain_core.prompts import PromptTemplate

load_dotenv()
model=ChatOpenAI()
st.header('Research Tools')
paper_input=st.selectbox('Select a research paper', ['Paper 1', 'Paper 2', 'Paper 3'])

style_input=st.selectbox('Select a writing style', ['Academic', 'Informal', 'Technical'])

length_input=st.selectbox('Select a summary length', ['Short', 'Medium', 'Long'])
#template form fynamically
template=PromptTemplate(
    template="Summarize {paper} in {style} style with a {length} length.",
    input_variables=["paper", "style", "length"]    
    
)
#fill the placeholders
prompt=template.invoke({
    "paper": paper_input,
    "style": style_input,
    "length": length_input
})

if st.button('Generate Summary'):
    result = model.invoke(prompt)
    st.write(result.content)
# Out:
# 2026-02-27 19:34:58.920
# ...
#   command:
#
#     streamlit run c:\ProgramData\anaconda3\Lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-02-27 19:34:58.927 Session state does not function when running a script without `streamlit run`
